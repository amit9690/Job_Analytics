# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd

# %%
url = "https://www.instahyre.com/search-jobs?company_size=0&isLandingPage=true&job_type=0&location=Anywhere+in+India&search=true"
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

# %%
data = []
a = 30
while (a>0):
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    view_link_div = soup.find_all('div',class_='opportunity-action-links')
    for i in view_link_div:
        link = i.find('a',href=True)
        driver.get(link['href'])
        time.sleep(2)
        s_page = BeautifulSoup(driver.page_source,"html.parser")
        c_info = s_page.find('div',class_='company-info')
        company_name = s_page.find('h2',class_='company-name').text
        div_info = c_info.find_all('div')
        f_year = div_info[0].text
        n_employee = div_info[1].text
        
        location = s_page.find('div',class_ = 'job-locations').find_all('span')[0].text
        designation = s_page.find('div',class_='profile-info').find('h1').text
        hr_name = s_page.find('span',class_='rec-name').text
        try:
            skills =','.join([x.text for x in  s_page.find('ul',{'id':'job-skills-description'}).find_all('li')])
        except:
            print(str(a)+' / '+company_name)
        data.append([company_name,f_year,n_employee,location,designation,hr_name,skills])
        driver.execute_script('history.back()')
        time.sleep(1)
        
    
    driver.execute_script('$(".pagination li:last").click()')
    time.sleep(3)
    a-=1
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[3], line 11
#       9 driver.get(link['href'])
#      10 time.sleep(2)
# ---> 11 s_page = BeautifulSoup(driver.page_source,"html.parser")
#      12 c_info = s_page.find('div',class_='company-info')
#      13 company_name = s_page.find('h2',class_='company-name').text
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.page_source(self)
#     437 @property
#     438 def page_source(self) -> str:
#     439     """Gets the source of the current page.
#     440
#     441     :Usage:
#    (...)
#     444             driver.page_source
#     445     """
# --> 446     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
#     344 if response:
# --> 345     self.error_handler.check_response(response)
#     346     response["value"] = self._unwrap_value(response.get("value", None))
#     347     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.141)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF629A352A2+57122]
# 	(No symbol) [0x00007FF6299AEA92]
# 	(No symbol) [0x00007FF62987E3AB]
# 	(No symbol) [0x00007FF62985E1B9]
# 	(No symbol) [0x00007FF6298DB417]
# 	(No symbol) [0x00007FF6298EE24F]
# 	(No symbol) [0x00007FF6298D6DB3]
# 	(No symbol) [0x00007FF6298AD2B1]
# 	(No symbol) [0x00007FF6298AE494]
# 	GetHandleVerifier [0x00007FF629CDEF82+2849794]
# 	GetHandleVerifier [0x00007FF629D31D24+3189156]
# 	GetHandleVerifier [0x00007FF629D2ACAF+3160367]
# 	GetHandleVerifier [0x00007FF629AC6D06+653702]
# 	(No symbol) [0x00007FF6299BA208]
# 	(No symbol) [0x00007FF6299B62C4]
# 	(No symbol) [0x00007FF6299B63F6]
# 	(No symbol) [0x00007FF6299A67A3]
# 	BaseThreadInitThunk [0x00007FF99C207614+20]
# 	RtlUserThreadStart [0x00007FF99DE826B1+33]

# %%
df = pd.DataFrame(data , columns = ['name','estab_year','employees_count','location','designation','hr_name','skills'])

# %%
df.to_csv('C:\\Users\\User\\Desktop\\company.csv')

# %%
df
# Out:
#                name       estab_year           employees_count  \
# 0           FalconX  Founded in 2018        50 - 200 employees
# 1           FalconX  Founded in 2018        50 - 200 employees
# 2          goGlocal  Founded in 2021         10 - 50 employees
# 3              IDfy  Founded in 2011       200 - 500 employees
# 4   Indium Software  Founded in 1999  More than 1000 employees
# 5        Kaleidofin  Founded in 2017        50 - 200 employees
# 6        Kaleidofin  Founded in 2017        50 - 200 employees
# 7         Lifesight  Founded in 2017        50 - 200 employees
# 8             Syndr  Founded in 2021          0 - 10 employees
# 9              Vymo  Founded in 2013        50 - 200 employees
# 10   Amazon Devices  Founded in 1994  More than 1000 employees
#
#                 location                                 designation  \
# 0              Bangalore        Finance Associate Controller (Drive)
# 1              Bangalore         Finance Associate Reporting (Drive)
# 2                 Mumbai            BDE / BDA - Inside Sales (Drive)
# 3                 Mumbai                 Key Account Manager (Drive)
# 4   Bangalore, Hyderabad  Data Analyst / Senior Data Analyst (Drive)
# 5     Bangalore, Chennai                      Data Scientist (Drive)
# 6     Bangalore, Chennai           Product Solution Engineer (Drive)
# 7              Bangalore                Inside Sales Manager (Drive)
# 8                  Delhi                    HR & Ops Manager (Drive)
# 9              Bangalore            Customer Success Manager (Drive)
# 10             Hyderabad                      Content Writer (Drive)
#
#                    hr_name                                             skills
# 0             Divya Kasula  Chartered Accountant,IFRS,Legal Compliance,Sta...
# 1             Divya Kasula  Chartered Accountant,Financial Reporting,Liqui...
# 2             Kreesha Shah                              Lead Generation,Sales
# 3         Stuti Srivastava  Business Development,Key Account Management,Le...
# 4            Mohamed Aslam         NumPy,Power BI,Python,R,SQL,Tableau,pandas
# 5     Natasha Jethanandani  Algorithms,Azure Machine Learning,Big Data,Clo...
# 6     Natasha Jethanandani  Amazon API Gateway,Azure API Management,C#,C++...
# 7   Madhuparna Chakraborty          International Sales,Lead Generation,Sales
# 8              Vyom Sharma  Employee Benefits,Employee Engagement,HR Opera...
# 9     Shashank Shrivastava  Customer Interaction,Customer Relationship,Cus...
# 10            Maria Joseph                    Content Writing,English Content
